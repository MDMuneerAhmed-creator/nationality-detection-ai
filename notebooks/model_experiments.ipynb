# %% [markdown]
# # Custom Scratch CNN Training Experiments
#
# This notebook demonstrates training custom Convolutional Neural Networks from scratch without any pretrained weights or transfer learning.
#
# ## Requirements:
# - 4 Independent Models: Nationality, Emotion, Age, Dress Colour
# - Layers: Conv2D -> BatchNorm -> ReLU -> MaxPool -> Dropout -> Dense -> Softmax
# - Random He/Kaiming Weight Initialization

# %%
import os
import sys
import torch
import torch.nn as nn

# Add root path
sys.path.append('..')
from backend.models import create_nationality_model, NATIONALITIES

model = create_nationality_model()
print('Nationality CNN Model Architecture:')
print(model)
